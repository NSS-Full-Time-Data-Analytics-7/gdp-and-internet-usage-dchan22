# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# Loading gdp dataset to pd, showing the shape of the df, 6868 rows and 4 columns
gdp = pd.read_csv('../data/gdp_percapita.csv', engine = 'python', skipfooter = 2)
print(gdp.head(6))
gdp.shape
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN
# (6868, 4)

# %%
# checking the first and last 5 of gdp.df
gdp
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2019  2065.036398              NaN
# 1        Afghanistan  2018  2033.779002              NaN
# 2        Afghanistan  2017  2058.383832              NaN
# 3        Afghanistan  2016  2057.062164              NaN
# 4        Afghanistan  2015  2068.265904              NaN
# ...              ...   ...          ...              ...
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN
#
# [6868 rows x 4 columns]

# %%
# Loading internet dataset to pd, showing the shape of the df, 4495 rows and 4 columns
internet = pd.read_csv('../data/internet_use.csv', nrows = 4495)
print(internet.tail(6))
internet.shape
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN
# (4495, 4)

# %%
# checking the internet.df, first and last 5
internet
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 0        Afghanistan  2014  6.390000              NaN
# 1        Afghanistan  2013  5.900000              NaN
# 2        Afghanistan  2012  5.454545              NaN
# 3        Afghanistan  2011  5.000000              NaN
# 4        Afghanistan  2010  4.000000              NaN
# ...              ...   ...       ...              ...
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN
#
# [4495 rows x 4 columns]

# %%
# Datatypes for gdp.df
gdp.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
# Datatypes  for internet.df
internet.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# 99. Take a look at the last 10 rows of each DataFrame in turn.

# %%
# Last 10 rows for gdp.df
gdp.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6858        Zimbabwe  1999  3600.849291              NaN
# 6859        Zimbabwe  1998  3653.920016              NaN
# 6860        Zimbabwe  1997  3580.048793              NaN
# 6861        Zimbabwe  1996  3520.430146              NaN
# 6862        Zimbabwe  1995  3226.413930              NaN
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %%
# Last 10 rows for internet.df
internet.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# 7. 	Drop the `value footnotes` column from both DataFrames. Check that this worked as expected.

# %%
# Dropping 'value footnotes' from gdp.df
gdp = gdp.drop('Value Footnotes', axis = 1)
gdp
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2019  2065.036398
# 1        Afghanistan  2018  2033.779002
# 2        Afghanistan  2017  2058.383832
# 3        Afghanistan  2016  2057.062164
# 4        Afghanistan  2015  2068.265904
# ...              ...   ...          ...
# 6863        Zimbabwe  1994  3263.934978
# 6864        Zimbabwe  1993  3033.504852
# 6865        Zimbabwe  1992  3054.889178
# 6866        Zimbabwe  1991  3426.598094
# 6867        Zimbabwe  1990  3324.348171
#
# [6868 rows x 3 columns]

# %%
# Dropping 'value footnotes' from internet.df
internet = internet.drop('Value Footnotes', axis = 1)
internet
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %%
# Renaming columns in gdp.df
gdp.columns = [ 'Country', 'Year', 'GDP_Per_Capita' ]
gdp
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
# Renaming columns in internet.df
internet.columns = ['Country', 'Year', 'Internet_Users_Pct']
internet
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# 10. Merge the two DataFrames to one. Merge **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`.

# %%
# merging
gdp_and_internet_use = gdp.merge(internet, how = 'outer', on = ['Country', 'Year'])
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2019     2065.036398                 NaN
# 1     Afghanistan  2018     2033.779002                 NaN
# 2     Afghanistan  2017     2058.383832                 NaN
# 3     Afghanistan  2016     2057.062164                 NaN
# 4     Afghanistan  2015     2068.265904                 NaN
# ...           ...   ...             ...                 ...
# 7900        Yemen  1999             NaN            0.056629
# 7901        Yemen  1998             NaN            0.023323
# 7902        Yemen  1997             NaN            0.015025
# 7903        Yemen  1996             NaN            0.000621
# 7904        Yemen  1990             NaN            0.000000
#
# [7905 rows x 4 columns]

# %%
# Reset index after merge
gdp_and_internet_use.reset_index(drop = True)
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2019     2065.036398                 NaN
# 1     Afghanistan  2018     2033.779002                 NaN
# 2     Afghanistan  2017     2058.383832                 NaN
# 3     Afghanistan  2016     2057.062164                 NaN
# 4     Afghanistan  2015     2068.265904                 NaN
# ...           ...   ...             ...                 ...
# 7900        Yemen  1999             NaN            0.056629
# 7901        Yemen  1998             NaN            0.023323
# 7902        Yemen  1997             NaN            0.015025
# 7903        Yemen  1996             NaN            0.000621
# 7904        Yemen  1990             NaN            0.000000
#
# [7905 rows x 4 columns]

# %%
gdp_and_internet_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7905 entries, 0 to 7904
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             7905 non-null   object
#  1   Year                7905 non-null   int64
#  2   GDP_Per_Capita      6868 non-null   float64
#  3   Internet_Users_Pct  4495 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 308.8+ KB

# %%
gdp_and_internet_use.tail(5)
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7900   Yemen  1999             NaN            0.056629
# 7901   Yemen  1998             NaN            0.023323
# 7902   Yemen  1997             NaN            0.015025
# 7903   Yemen  1996             NaN            0.000621
# 7904   Yemen  1990             NaN            0.000000

# %%
# Subset to keep '2004, 2009, 2014'
chosen_years = gdp_and_internet_use[gdp_and_internet_use['Year'].isin([2004, 2009, 2014])]
chosen_years
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5               Afghanistan  2014     2102.385234            6.390000
# 10              Afghanistan  2009     1758.904043            3.550000
# 15              Afghanistan  2004     1200.278256            0.105809
# 23                  Albania  2014    11623.866679           60.100000
# 28                  Albania  2009    10346.864199           41.200000
# ...                     ...   ...             ...                 ...
# 7868  Virgin Islands (U.S.)  2009             NaN           27.396510
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7885                  Yemen  2014             NaN           22.550000
# 7890                  Yemen  2009             NaN            9.960000
# 7895                  Yemen  2004             NaN            0.881223
#
# [830 rows x 4 columns]

# %%
chosen_years.head(10)
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5   Afghanistan  2014     2102.385234            6.390000
# 10  Afghanistan  2009     1758.904043            3.550000
# 15  Afghanistan  2004     1200.278256            0.105809
# 23      Albania  2014    11623.866679           60.100000
# 28      Albania  2009    10346.864199           41.200000
# 33      Albania  2004     7604.838002            2.420388
# 53      Algeria  2014    11512.705405           18.090000
# 58      Algeria  2009    10782.361398           11.230000
# 63      Algeria  2004    10058.435939            4.634475
# 83       Angola  2014     8239.828837           21.260000

# %%
# Reset after subset
chosen_years = chosen_years.reset_index(drop = True)
chosen_years
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0              Afghanistan  2014     2102.385234            6.390000
# 1              Afghanistan  2009     1758.904043            3.550000
# 2              Afghanistan  2004     1200.278256            0.105809
# 3                  Albania  2014    11623.866679           60.100000
# 4                  Albania  2009    10346.864199           41.200000
# ..                     ...   ...             ...                 ...
# 825  Virgin Islands (U.S.)  2009             NaN           27.396510
# 826  Virgin Islands (U.S.)  2004             NaN           27.377009
# 827                  Yemen  2014             NaN           22.550000
# 828                  Yemen  2009             NaN            9.960000
# 829                  Yemen  2004             NaN            0.881223
#
# [830 rows x 4 columns]

# %% [markdown]
# 14. Create three new DataFrames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
#2004 df
data_2004 = chosen_years[chosen_years['Year'].isin([2004])]
print(data_2004)
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2              Afghanistan  2004     1200.278256            0.105809
# 5                  Albania  2004     7604.838002            2.420388
# 8                  Algeria  2004    10058.435939            4.634475
# 11                  Angola  2004     5593.241537            0.464815
# 14     Antigua and Barbuda  2004    18745.681534           24.266544
# ..                     ...   ...             ...                 ...
# 817     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 820              Venezuela  2004             NaN            8.404470
# 823               Viet Nam  2004             NaN            7.642409
# 826  Virgin Islands (U.S.)  2004             NaN           27.377009
# 829                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %%
#Checking the data type
type(data_2004)
# Out:
# pandas.core.frame.DataFrame

# %%
# Reset after making new df
data_2004 = data_2004.reset_index(drop = True)
data_2004
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0              Afghanistan  2004     1200.278256            0.105809
# 1                  Albania  2004     7604.838002            2.420388
# 2                  Algeria  2004    10058.435939            4.634475
# 3                   Angola  2004     5593.241537            0.464815
# 4      Antigua and Barbuda  2004    18745.681534           24.266544
# ..                     ...   ...             ...                 ...
# 271     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 272              Venezuela  2004             NaN            8.404470
# 273               Viet Nam  2004             NaN            7.642409
# 274  Virgin Islands (U.S.)  2004             NaN           27.377009
# 275                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %%
# 2009 df
data_2009 = chosen_years[chosen_years['Year'].isin([2009])]
print(data_2009)
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1              Afghanistan  2009     1758.904043             3.55000
# 4                  Albania  2009    10346.864199            41.20000
# 7                  Algeria  2009    10782.361398            11.23000
# 10                  Angola  2009     7643.493749             6.00000
# 13     Antigua and Barbuda  2009    20046.839017            42.00000
# ..                     ...   ...             ...                 ...
# 816     T.F.Y.R. Macedonia  2009             NaN            51.77000
# 819              Venezuela  2009             NaN            32.70000
# 822               Viet Nam  2009             NaN            26.55000
# 825  Virgin Islands (U.S.)  2009             NaN            27.39651
# 828                  Yemen  2009             NaN             9.96000
#
# [277 rows x 4 columns]

# %%
# checking data type
type(data_2009)
# Out:
# pandas.core.frame.DataFrame

# %%
# Reset after making new df
data_2009 = data_2009.reset_index(drop = True)
data_2009
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0              Afghanistan  2009     1758.904043             3.55000
# 1                  Albania  2009    10346.864199            41.20000
# 2                  Algeria  2009    10782.361398            11.23000
# 3                   Angola  2009     7643.493749             6.00000
# 4      Antigua and Barbuda  2009    20046.839017            42.00000
# ..                     ...   ...             ...                 ...
# 272     T.F.Y.R. Macedonia  2009             NaN            51.77000
# 273              Venezuela  2009             NaN            32.70000
# 274               Viet Nam  2009             NaN            26.55000
# 275  Virgin Islands (U.S.)  2009             NaN            27.39651
# 276                  Yemen  2009             NaN             9.96000
#
# [277 rows x 4 columns]

# %%
# 2014 df
data_2014 = chosen_years[chosen_years['Year'].isin([2014])]
print(data_2014.head())
# Out:
#                 Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0           Afghanistan  2014     2102.385234                6.39
# 3               Albania  2014    11623.866679               60.10
# 6               Algeria  2014    11512.705405               18.09
# 9                Angola  2014     8239.828837               21.26
# 12  Antigua and Barbuda  2014    18104.241470               64.00

# %%
# checking data type
type(data_2014)
# Out:
# pandas.core.frame.DataFrame

# %%
# Reset after making new df
data_2014 = data_2014.reset_index(drop = True)
data_2014
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0              Afghanistan  2014     2102.385234                6.39
# 1                  Albania  2014    11623.866679               60.10
# 2                  Algeria  2014    11512.705405               18.09
# 3                   Angola  2014     8239.828837               21.26
# 4      Antigua and Barbuda  2014    18104.241470               64.00
# ..                     ...   ...             ...                 ...
# 272     T.F.Y.R. Macedonia  2014             NaN               68.06
# 273              Venezuela  2014             NaN               57.00
# 274               Viet Nam  2014             NaN               48.31
# 275  Virgin Islands (U.S.)  2014             NaN               50.07
# 276                  Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %% [markdown]
# 15. Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options).

# %%
data_2014.sort_values(by = 'Internet_Users_Pct')
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 246  Dem. People's Rep. of Korea  2014             NaN                0.00
# 248                      Eritrea  2014             NaN                0.99
# 215                  Timor-Leste  2014     3264.568070                1.14
# 28                       Burundi  2014      886.235777                1.38
# 268                      Somalia  2014             NaN                1.63
# ..                           ...   ...             ...                 ...
# 223                       Tuvalu  2014     3450.793169                 NaN
# 229          Upper middle income  2014    14275.343977                 NaN
# 233                      Vietnam  2014     6098.489609                 NaN
# 234           West Bank and Gaza  2014     5967.073437                 NaN
# 235                        World  2014    15189.648507                 NaN
#
# [277 rows x 4 columns]

# %%
# Highest internet users pct for 2014 -Iceland 98.16
data_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 90               Iceland  2014    49652.149500               98.16
# 19               Bermuda  2014    77361.104881               96.80
# 160               Norway  2014    62589.373548               96.30
# 50               Denmark  2014    52214.537753               95.99
# 238              Andorra  2014             NaN               95.90
# ..                   ...   ...             ...                 ...
# 223               Tuvalu  2014     3450.793169                 NaN
# 229  Upper middle income  2014    14275.343977                 NaN
# 233              Vietnam  2014     6098.489609                 NaN
# 234   West Bank and Gaza  2014     5967.073437                 NaN
# 235                World  2014    15189.648507                 NaN
#
# [277 rows x 4 columns]

# %%
# Lowest internet users pct for 2014 - (Dem. People's Rep. of Korea 0.00) Not counting 0 - Eritrea 0.99
data_2014.sort_values(by = 'Internet_Users_Pct', ascending = True)
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 246  Dem. People's Rep. of Korea  2014             NaN                0.00
# 248                      Eritrea  2014             NaN                0.99
# 215                  Timor-Leste  2014     3264.568070                1.14
# 28                       Burundi  2014      886.235777                1.38
# 268                      Somalia  2014             NaN                1.63
# ..                           ...   ...             ...                 ...
# 223                       Tuvalu  2014     3450.793169                 NaN
# 229          Upper middle income  2014    14275.343977                 NaN
# 233                      Vietnam  2014     6098.489609                 NaN
# 234           West Bank and Gaza  2014     5967.073437                 NaN
# 235                        World  2014    15189.648507                 NaN
#
# [277 rows x 4 columns]

# %%
# Highest internet users pct for 2009 - Iceland 93.00
data_2009.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 89               Iceland  2009    48177.084123               93.00
# 159               Norway  2009    61886.564498               92.08
# 207               Sweden  2009    45638.035577               91.00
# 152          Netherlands  2009    51772.424928               89.63
# 126           Luxembourg  2009   104932.811953               87.31
# ..                   ...   ...             ...                 ...
# 213           The Gambia  2009     2283.183556                 NaN
# 227  Upper middle income  2009    11212.934078                 NaN
# 231              Vietnam  2009     4830.304958                 NaN
# 232   West Bank and Gaza  2009     5250.116075                 NaN
# 233                World  2009    13396.524163                 NaN
#
# [277 rows x 4 columns]

# %%
# Lowest internet users pct for 2009 - Not counting 0 - Timor-Leste 0.185
data_2009.sort_values(by = 'Internet_Users_Pct', ascending = True)
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 244  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 214                  Timor-Leste  2009     2724.770973            0.185252
# 148                      Myanmar  2009     2874.780227            0.220000
# 187                 Sierra Leone  2009     1372.392285            0.260000
# 31                      Cambodia  2009     2603.583778            0.530000
# ..                           ...   ...             ...                 ...
# 213                   The Gambia  2009     2283.183556                 NaN
# 227          Upper middle income  2009    11212.934078                 NaN
# 231                      Vietnam  2009     4830.304958                 NaN
# 232           West Bank and Gaza  2009     5250.116075                 NaN
# 233                        World  2009    13396.524163                 NaN
#
# [277 rows x 4 columns]

# %%
# Highest internet users pct for 2004 - Sweden 83.89
data_2004.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 205               Sweden  2004    44496.023401               83.89
# 88               Iceland  2004    45145.545658               83.88
# 49               Denmark  2004    50607.628971               80.93
# 158               Norway  2004    60893.410993               77.69
# 256      Korea (Rep. of)  2004             NaN               72.70
# ..                   ...   ...             ...                 ...
# 219               Tuvalu  2004     3336.952920                 NaN
# 225  Upper middle income  2004     8567.061394                 NaN
# 229              Vietnam  2004     3689.732423                 NaN
# 230   West Bank and Gaza  2004     4485.525458                 NaN
# 231                World  2004    12077.823821                 NaN
#
# [276 rows x 4 columns]

# %%
# Lowest internet users pct for 2004 - Not counting 0 - Myanmar 0.024
data_2004.sort_values(by = 'Internet_Users_Pct', ascending = True)
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 242  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 147                      Myanmar  2004     1696.881760            0.024337
# 119                      Liberia  2004     1181.546158            0.031011
# 207                   Tajikistan  2004     1737.743630            0.077480
# 0                    Afghanistan  2004     1200.278256            0.105809
# ..                           ...   ...             ...                 ...
# 219                       Tuvalu  2004     3336.952920                 NaN
# 225          Upper middle income  2004     8567.061394                 NaN
# 229                      Vietnam  2004     3689.732423                 NaN
# 230           West Bank and Gaza  2004     4485.525458                 NaN
# 231                        World  2004    12077.823821                 NaN
#
# [276 rows x 4 columns]

# %% [markdown]
# 18. Which country had the highest gdp per capita in 2014? What was the gdp per capita?

# %%
# Highest 2014 gdp per capita - Macao SAR, China 156514.133850
data_2014.sort_values(by = 'GDP_Per_Capita', ascending = False)
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 128       Macao SAR, China  2014   156514.133850                 NaN
# 127             Luxembourg  2014   108760.916030               94.67
# 177                  Qatar  2014    95578.416973               91.49
# 189              Singapore  2014    87808.663157               82.00
# 19                 Bermuda  2014    77361.104881               96.80
# ..                     ...   ...             ...                 ...
# 272     T.F.Y.R. Macedonia  2014             NaN               68.06
# 273              Venezuela  2014             NaN               57.00
# 274               Viet Nam  2014             NaN               48.31
# 275  Virgin Islands (U.S.)  2014             NaN               50.07
# 276                  Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %%
# Lowest 2014 gdp per capita - Central Africa Republic 822.610458
data_2014.sort_values(by = 'GDP_Per_Capita', ascending = True)
# Out:
#                       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 36   Central African Republic  2014      822.610458                 NaN
# 28                    Burundi  2014      886.235777                1.38
# 130                    Malawi  2014     1027.208496                5.83
# 49            Dem. Rep. Congo  2014     1029.790785                 NaN
# 156                     Niger  2014     1127.615541                1.95
# ..                        ...   ...             ...                 ...
# 272        T.F.Y.R. Macedonia  2014             NaN               68.06
# 273                 Venezuela  2014             NaN               57.00
# 274                  Viet Nam  2014             NaN               48.31
# 275     Virgin Islands (U.S.)  2014             NaN               50.07
# 276                     Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %% [markdown]
# 21. Create some scatterplots:
#     a.  2004 Percent Using the Internet vs GDP Per Capita
#     b.	2009 Percent Using the Internet vs GDP Per Capita
#     c.	2014 Percent Using the Internet vs GDP Per Capita

# %%
data_2004.plot.scatter('Internet_Users_Pct','GDP_Per_Capita');

# %%
data_2009.plot.scatter('Internet_Users_Pct','GDP_Per_Capita', color ='r');

# %%
plt.scatter(data = data_2014, x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', color = 'g')
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita');

# %% [markdown]
# 22.	Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.
#
# Through out the three years the pattern looks almost the same. There are clusters concentrated where gdp are in the low ranges with internet users pct are low as well. This might be rural areas.

# %% [markdown]
# 23.	Look at the distribution of gdp per capita values for 2014. Is it unimodal?
#
# it's not unimodal

# %% [markdown]
# 24.	Look at the distribution of Internet Use for 2014. Is it unimodal?
#
# It's not unimodal

# %%
# What are the top 5 countries in terms of internet use in 2014?
# Highest internet users pct for 2014 -Iceland , Bermuda, Norway, Denmark, Andorra
data_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 90               Iceland  2014    49652.149500               98.16
# 19               Bermuda  2014    77361.104881               96.80
# 160               Norway  2014    62589.373548               96.30
# 50               Denmark  2014    52214.537753               95.99
# 238              Andorra  2014             NaN               95.90
# ..                   ...   ...             ...                 ...
# 223               Tuvalu  2014     3450.793169                 NaN
# 229  Upper middle income  2014    14275.343977                 NaN
# 233              Vietnam  2014     6098.489609                 NaN
# 234   West Bank and Gaza  2014     5967.073437                 NaN
# 235                World  2014    15189.648507                 NaN
#
# [277 rows x 4 columns]

# %% [markdown]
# 26.	Create a DataFrame called top_5_internet **from the combined DataFrame that has all three years _for the 5 countries that had the greatest 2014 internet usage_**. You should have 15 rows. Check that this is true.

# %%
top_5_internet = chosen_years[chosen_years['Country'].isin(['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra'])]
top_5_internet.shape
# Out:
# (15, 4)

# %%
top_5_internet
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 57   Bermuda  2014    77361.104881           96.800000
# 58   Bermuda  2009    89961.982744           83.250000
# 59   Bermuda  2004    90195.811033           60.990867
# 149  Denmark  2014    52214.537753           95.990000
# 150  Denmark  2009    50274.075696           86.840000
# 151  Denmark  2004    50607.628971           80.930000
# 267  Iceland  2014    49652.149500           98.160000
# 268  Iceland  2009    48177.084123           93.000000
# 269  Iceland  2004    45145.545658           83.880000
# 477   Norway  2014    62589.373548           96.300000
# 478   Norway  2009    61886.564498           92.080000
# 479   Norway  2004    60893.410993           77.690000
# 708  Andorra  2014             NaN           95.900000
# 709  Andorra  2009             NaN           78.530000
# 710  Andorra  2004             NaN           26.837954

# %%
g = sns.FacetGrid(top_5_internet, col = 'Year', row = 'Country')
g.map(sns.scatterplot, 'Year', 'Internet_Users_Pct', marker = '>');

# %%
#Lowest internet users pct for 2014
data_2014.sort_values(by = 'Internet_Users_Pct', ascending = True)
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 246  Dem. People's Rep. of Korea  2014             NaN                0.00
# 248                      Eritrea  2014             NaN                0.99
# 215                  Timor-Leste  2014     3264.568070                1.14
# 28                       Burundi  2014      886.235777                1.38
# 268                      Somalia  2014             NaN                1.63
# ..                           ...   ...             ...                 ...
# 223                       Tuvalu  2014     3450.793169                 NaN
# 229          Upper middle income  2014    14275.343977                 NaN
# 233                      Vietnam  2014     6098.489609                 NaN
# 234           West Bank and Gaza  2014     5967.073437                 NaN
# 235                        World  2014    15189.648507                 NaN
#
# [277 rows x 4 columns]

# %%
low5_internet2014 = data_2014.sort_values(by = 'Internet_Users_Pct', ascending = True).head()

# %%
countries_internet_2014 = low5_internet2014['Country']

# %%
countries_internet_2014
# Out:
# 246    Dem. People's Rep. of Korea
# 248                        Eritrea
# 215                    Timor-Leste
# 28                         Burundi
# 268                        Somalia
# Name: Country, dtype: object

# %%
lowest_5_internet = chosen_years[chosen_years['Country'].isin(countries_internet_2014)]
lowest_5_internet.shape
# Out:
# (14, 4)

# %%
lowest_5_internet
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 84                       Burundi  2014      886.235777            1.380000
# 85                       Burundi  2009      831.564131            0.900000
# 86                       Burundi  2004      817.460585            0.349060
# 641                  Timor-Leste  2014     3264.568070            1.140000
# 642                  Timor-Leste  2009     2724.770973            0.185252
# 643                  Timor-Leste  2004     2258.608056                 NaN
# 732  Dem. People's Rep. of Korea  2014             NaN            0.000000
# 733  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 734  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 740                      Eritrea  2014             NaN            0.990000
# 741                      Eritrea  2009             NaN            0.540000
# ...

# %%
l = sns.FacetGrid(lowest_5_internet, col = 'Year', row = 'Country', aspect = 1.5)
l.map(sns.scatterplot, 'Year', 'Internet_Users_Pct', color = 'r', marker = 's');

# %% [markdown]
# 29.	Find the top 5 countries for 2014 in terms of GDP per capita; create a DataFrame to look at 10-year trends (use 2004, 2009, 2014 to look at the 10-year trend) in gdp per capita for the 5 countries with the highest 2014 GDP per capita. Use a seaborn facet grid for this.

# %%
top5_gdp2014 = data_2014.sort_values(by = 'GDP_Per_Capita', ascending = False).head()

# %%
countries_gdp_2014 = top5_gdp2014['Country']

# %%
countries_gdp_2014
# Out:
# 128    Macao SAR, China
# 127          Luxembourg
# 177               Qatar
# 189           Singapore
# 19              Bermuda
# Name: Country, dtype: object

# %%
top_5_gdp = chosen_years[chosen_years['Country'].isin(countries_gdp_2014)]
top_5_gdp.shape
# Out:
# (15, 4)

# %%
top_5_gdp
# Out:
#               Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 57            Bermuda  2014    77361.104881           96.800000
# 58            Bermuda  2009    89961.982744           83.250000
# 59            Bermuda  2004    90195.811033           60.990867
# 378        Luxembourg  2014   108760.916030           94.670000
# 379        Luxembourg  2009   104932.811953           87.310000
# 380        Luxembourg  2004   102708.212547           65.880000
# 381  Macao SAR, China  2014   156514.133850                 NaN
# 382  Macao SAR, China  2009    95939.340822                 NaN
# 383  Macao SAR, China  2004    72944.409424                 NaN
# 528             Qatar  2014    95578.416973           91.490000
# 529             Qatar  2009    89954.519993           53.100000
# 530             Qatar  2004    93748.301216           20.701648
# 564         Singapore  2014    87808.663157           82.000000
# 565         Singapore  2009    69466.581746           69.000000
# ...

# %%
gr = sns.FacetGrid(top_5_gdp, col = 'Year', row = 'Country', aspect = 1.2)
gr.map(sns.scatterplot, 'Year', 'GDP_Per_Capita', color = 'c', marker = 'D');

# %%
low5_gdp2014 = data_2014.sort_values(by = 'GDP_Per_Capita', ascending = True).head()
low5_gdp2014
# Out:
#                       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 36   Central African Republic  2014      822.610458                 NaN
# 28                    Burundi  2014      886.235777                1.38
# 130                    Malawi  2014     1027.208496                5.83
# 49            Dem. Rep. Congo  2014     1029.790785                 NaN
# 156                     Niger  2014     1127.615541                1.95

# %%
countries_low_2014gdp = low5_gdp2014['Country']
countries_low_2014gdp
# Out:
# 36     Central African Republic
# 28                      Burundi
# 130                      Malawi
# 49              Dem. Rep. Congo
# 156                       Niger
# Name: Country, dtype: object

# %%
lowest_5_gdp = chosen_years[chosen_years['Country'].isin(countries_low_2014gdp)]
lowest_5_gdp.shape
# Out:
# (15, 4)

# %%
lowest_5_gdp
# Out:
#                       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 84                    Burundi  2014      886.235777            1.380000
# 85                    Burundi  2009      831.564131            0.900000
# 86                    Burundi  2004      817.460585            0.349060
# 107  Central African Republic  2014      822.610458                 NaN
# 108  Central African Republic  2009     1161.189475                 NaN
# 109  Central African Republic  2004     1037.846766                 NaN
# 146           Dem. Rep. Congo  2014     1029.790785                 NaN
# 147           Dem. Rep. Congo  2009      835.611696                 NaN
# 148           Dem. Rep. Congo  2004      757.685942                 NaN
# 387                    Malawi  2014     1027.208496            5.830000
# 388                    Malawi  2009      932.867635            1.070000
# 389                    Malawi  2004      775.346132            0.347505
# ...

# %%
gro = sns.FacetGrid(lowest_5_gdp, col = 'Year', row = 'Country', aspect = 1.3)
gro.map(sns.scatterplot, 'Year', 'GDP_Per_Capita', color = 'g');

# %% [markdown]
# 30.	Is there anything surprising or unusual in any of these plots? Searching on the internet, can you find any possible explanations for unusual findings?
#
# In the top5 and lowest5 most stayed steady or shows growth. But in 2014 Central African Republic had a steep drop. Slowed economic growth

# %%
lowest_5_gdp.plot('Year', 'GDP_Per_Capita');
